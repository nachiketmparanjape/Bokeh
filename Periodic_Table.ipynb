# %%
from bokeh.sampledata.periodic_table import elements
from bokeh.io import output_notebook, show
from bokeh.models import Range1d, PanTool, ResetTool, HoverTool, ColumnDataSource
from bokeh.plotting import figure

output_notebook()

f = figure()

elements = elements.dropna()
colormap = {'gas':'yellow','liquid':'orange','solid':'red'}
elements['color'] = [colormap[x] for x in elements['standard state']]

gas = ColumnDataSource(elements[elements['standard state'] == 'gas'])
liquid = ColumnDataSource(elements[elements['standard state'] == 'liquid'])
solid = ColumnDataSource(elements[elements['standard state'] == 'solid'])

f.circle(x="atomic radius", y="boiling point",
         size=[i/10 for i in gas.data["van der Waals radius"]],
         fill_alpha=0.2,color="color",line_dash=[5,3],legend='Gas',source=gas)

f.circle(x="atomic radius", y="boiling point",
         size=[i/10 for i in liquid.data["van der Waals radius"]],
         fill_alpha=0.2,color="color",line_dash=[5,3],legend='Liquid',source=liquid)

f.circle(x="atomic radius", y="boiling point",
         size=[i/10 for i in solid.data["van der Waals radius"]],
         fill_alpha=0.2,color="color",line_dash=[5,3],legend='Solid',source=solid)

f.xaxis.axis_label="Atomic radius"
f.yaxis.axis_label="Boiling point"

#Tools
f.toolbar_location='above'
f.toolbar.logo = None

#Title
f.title.text = 'Elements'
f.title.text_font_size = "44px"
f.title.align = "center"

#Stylizing the plot area
f.plot_width=1500
f.plot_height=800
f.background_fill_color = "#CD5C5C"
f.background_fill_alpha = 0.1

show(f)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="31ea90bb-ef09-4974-8fc3-f4d4cf7d56b4">Loading BokehJS ...</span>
#     </div>
# C:\Users\labuser\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\labuser\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# C:\Users\labuser\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# C:\Users\labuser\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f24d3083-77ac-4f9e-84a4-5c4fd55bc97a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f24d3083-77ac-4f9e-84a4-5c4fd55bc97a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f24d3083-77ac-4f9e-84a4-5c4fd55bc97a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f24d3083-77ac-4f9e-84a4-5c4fd55bc97a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"95f5b3fb-9c5d-4f96-8ac0-26e8d426e1f3":{"roots":{"references":[{"attributes":{"callback":null},"id":"a64c4b43-156c-4d17-aae3-49ff85948afd","type":"DataRange1d"},{"attributes":{"data_source":{"id":"f77059de-09a9-4b58-a947-9dabe06f305f","type":"ColumnDataSource"},"glyph":{"id":"a06a4cd2-0809-42a3-87e9-c88ff015543e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"c8b3c35c-3f46-49dc-bed3-9c456d846cae","type":"Circle"},"selection_glyph":null},"id":"4ef629b2-3093-4481-81c4-4deb772ee202","type":"GlyphRenderer"},{"attributes":{},"id":"d7c86e37-0bea-4b50-b4e0-348c95959deb","type":"ToolEvents"},{"attributes":{},"id":"3d1a3714-2c2d-44c5-863a-12d517e944e9","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["atomic number","symbol","name","atomic mass","CPK","electronic configuration","electronegativity","atomic radius","ion radius","van der Waals radius","IE-1","EA","standard state","bonding type","melting point","boiling point","density","metal","year discovered","group","period","color","index","size"],"data":{"CPK":["#3050F8","#FF0D0D","#90E050","#1FF01F"],"EA":[-7.0,-141.0,-328.0,-349.0],"IE-1":[1402.0,1314.0,1681.0,1251.0],"atomic mass":["14.0067","15.9994","18.9984032","35.453"],"atomic number":[7,8,9,17],"atomic radius":[75.0,73.0,71.0,99.0],"boiling point":[77.0,90.0,85.0,239.0],"bonding type":["diatomic","diatomic","atomic","covalent network"],"color":["yellow","yellow","yellow","yellow"],"density":[0.0,0.0,0.0,0.0],"electronegativity":[3.04,3.44,3.98,3.16],"electronic configuration":["[He] 2s2 2p3","[He] 2s2 2p4","[He] 2s2 2p5","[Ne] 3s2 3p5"],"group":["15","16","17","17"],"index":[6,7,8,16],"ion radius":["146 (-3)","140 (-2)","133 (-1)","181 (-1)"],"melting point":[63.0,55.0,54.0,172.0],"metal":["nonmetal","nonmetal","halogen","halogen"],"name":["Nitrogen","Oxygen","Fluorine","Chlorine"],"period":[2,2,2,3],"size":[15.5,15.2,14.7,17.5],"standard state":["gas","gas","gas","gas"],"symbol":["N","O","F","Cl"],"van der Waals radius":[155.0,152.0,147.0,175.0],"year discovered":["1772","1774","1670","1774"]}},"id":"f77059de-09a9-4b58-a947-9dabe06f305f","type":"ColumnDataSource"},{"attributes":{"background_fill_alpha":{"value":0.1},"background_fill_color":{"value":"#CD5C5C"},"below":[{"id":"a2a0ba42-d785-405c-a3c9-19d7082aa905","type":"LinearAxis"}],"left":[{"id":"69b1438c-ee54-4507-ba56-86cc9a1468da","type":"LinearAxis"}],"plot_height":800,"plot_width":1500,"renderers":[{"id":"a2a0ba42-d785-405c-a3c9-19d7082aa905","type":"LinearAxis"},{"id":"7c490395-71d7-44c3-aacf-71fcdacbd227","type":"Grid"},{"id":"69b1438c-ee54-4507-ba56-86cc9a1468da","type":"LinearAxis"},{"id":"432198ac-c54b-4bee-80a2-0f4ea897f685","type":"Grid"},{"id":"5691a2a0-b1a3-4c68-83f7-33e6a6a2f05f","type":"BoxAnnotation"},{"id":"dab18b73-b8e4-42e2-9e12-7da8147c9d5c","type":"Legend"},{"id":"4ef629b2-3093-4481-81c4-4deb772ee202","type":"GlyphRenderer"},{"id":"3cd7db15-52ef-4494-a7cc-32c0485ed1e0","type":"GlyphRenderer"},{"id":"97e4202e-4ca8-416d-848d-fe47a92aaefa","type":"GlyphRenderer"}],"title":{"id":"8e843130-4ed6-4098-ba53-563e08ac9061","type":"Title"},"tool_events":{"id":"d7c86e37-0bea-4b50-b4e0-348c95959deb","type":"ToolEvents"},"toolbar":{"id":"8859b9a6-9ca9-4bbe-98de-b65bd326c44d","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"a64c4b43-156c-4d17-aae3-49ff85948afd","type":"DataRange1d"},"y_range":{"id":"a0069b43-6f85-49c1-86ed-38baaa545b68","type":"DataRange1d"}},"id":"08ab61e3-4948-4723-bd1d-5ad8ee42591b","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Atomic radius","formatter":{"id":"3d1a3714-2c2d-44c5-863a-12d517e944e9","type":"BasicTickFormatter"},"plot":{"id":"08ab61e3-4948-4723-bd1d-5ad8ee42591b","subtype":"Figure","type":"Plot"},"ticker":{"id":"ee31f78c-0a24-4573-a552-1c5183b4c3b5","type":"BasicTicker"}},"id":"a2a0ba42-d785-405c-a3c9-19d7082aa905","type":"LinearAxis"},{"attributes":{"label":{"value":"Gas"},"renderers":[{"id":"4ef629b2-3093-4481-81c4-4deb772ee202 ...
